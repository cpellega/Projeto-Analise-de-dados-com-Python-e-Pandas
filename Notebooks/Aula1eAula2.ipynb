# %%
print("Olá Mundo!!")
# Out:
# Olá Mundo!!

# %%
print("Estou aprendendo Python com Pandas !!!")
# Out:
# Estou aprendendo Python com Pandas !!!

# %%
"Estou aprendendo Python com Pandas !!!"
# Out:
# 'Estou aprendendo Python com Pandas !!!'

# %%
1+1\
# Out:
# 2

# %%
10 - 2
# Out:
# 8

# %%
# Este é um comentário

# %%
#Multiplicação
1234 * 5
# Out:
# 6170

# %%
#Divisão
50 / 5
# Out:
# 10.0

# %%
# Trabalhando com variáveis
a = 4
b = 6

# %%
a + b
# Out:
# 10

# %%
# Criando uma Strign
frase = "Python para análise de dados"

# %%
frase[0]
# Out:
# 'P'

# %%
frase[0:10
      ]
# Out:
# 'Python par'

# %%
frase[0:]
# Out:
# 'Python para análise de dados'

# %%
frase.count("dados")
# Out:
# 1

# %%
frase.count("a")
# Out:
# 4

# %%
frase.lower()
# Out:
# 'python para análise de dados'

# %%
frase.capitalize()
# Out:
# 'Python para análise de dados'

# %%
frase.upper()
# Out:
# 'PYTHON PARA ANÁLISE DE DADOS'

# %%
frase.replace("Python","Frase")
# Out:
# 'Frase para análise de dados'

# %%
frase
# Out:
# 'Python para análise de dados'

# %%
frase = frase.upper()

# %%
frase
# Out:
# 'PYTHON PARA ANÁLISE DE DADOS'

# %%
#Estrutura de dados

#Criando uma lista chamada aniamais
animals = [1,2,3]
animals
# Out:
# [1, 2, 3]

# %%
animals = ["peixe", "gato" ,"cachorro", "porco"]
animals
# Out:
# ['peixe', 'gato', 'cachorro', 'porco']

# %%
#Imprimento primeiro elemento da lista
animals[0]
# Out:
# 'peixe'

# %%
#Imprimento o 4o elemento
animals[3]
# Out:
# 'porco'

# %%
#substituindo o primeiro elemento da lista
animals[0]="tubarao"

# %%
animals
# Out:
# ['tubarao', 'gato', 'cachorro', 'porco']

# %%
#Removendo elemento da lista
animals.remove("gato")

# %%
animals
# Out:
# ['tubarao', 'cachorro', 'porco']

# %%
#tamanho da lissta
len(animals)
# Out:
# 3

# %%
#ver se um elemento esta na lista
"porco" in animals
# Out:
# True

# %%
lista = [500, 30, 80, 10]

# %%
lista
# Out:
# [500, 30, 80, 10]

# %%
max(lista)
min(lista)
# Out:
# 10

# %%
max(lista)
# Out:
# 500

# %%
#acrescentar animal na lista
animals.append("leão")

# %%
animals
# Out:
# ['tubarao', 'cachorro', 'porco', 'leão']

# %%
animals.extend(["pato","girafa","elefante"])

# %%
animals
# Out:
# ['tubarao', 'cachorro', 'porco', 'leão', 'pato', 'girafa', 'elefante']

# %%
animals.count
# Out:
# <function list.count>

# %%
animals.count("gato")
# Out:
# 0

# %%
lista.sort
# Out:
# <function list.sort>

# %%
lista.sort()
lista
# Out:
# [10, 30, 80, 500]

# %%
#Tuplas
tp = ("banan","gato",60,65.5
      )

# %%
tp
# Out:
# ('banan', 'gato', 60, 65.5)

# %%
#tuplas são imutável
#lista podem ser alteradas

# %%
  tp[0:3]
# Out:
# ('banan', 'gato', 60)

# %%
#Dicionários
dc = {"pera":20, "Banana":30, "Laranja":15, "Uva":5}

# %%
dc
# Out:
# {'Banana': 30, 'Laranja': 15, 'Uva': 5, 'pera': 20}

# %%
dc["Laranja"]
# Out:
# 15

# %%
#Atualizando o valor de Laranja
dc["Laranja"] = 100
dc
# Out:
# {'Banana': 30, 'Laranja': 100, 'Uva': 5, 'pera': 20}

# %%
#retornando chaves
dc.keys()
# Out:
# dict_keys(['pera', 'Banana', 'Laranja', 'Uva'])

# %%
dc.values()
# Out:
# dict_values([20, 30, 100, 5])

# %%
dc.setdefault("limao",22)
# Out:
# 22

# %%
dc
# Out:
# {'Banana': 30, 'Laranja': 100, 'Uva': 5, 'limao': 22, 'pera': 20}
